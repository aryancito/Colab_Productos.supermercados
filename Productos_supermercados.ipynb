# %% [markdown]
# <a href="https://colab.research.google.com/github/aryancito/Colab_Productos.supermercados/blob/main/Productos_supermercados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import data_table
data_table.enable_dataframe_formatter()
from vega_datasets import data
import datetime
from datetime import datetime

# %%
df=pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vSLmdqzcf9RF0E-_ZEB2XonqMmzHNa9DJrV1P-RjaeAWycQ3z3qeUkQgGOX9Uqe0kaL1EzebnqQl3Fy/pub?gid=159971742&single=true&output=csv")

# %%
from google.colab import data_table
from vega_datasets import data

data_table.enable_dataframe_formatter()
df
# Out:
# Warning: total number of rows (500000) exceeds max_rows (20000). Falling back to pandas display.
#          supermarket                                           category  \
# 0       mercadona-es                 postres_y_yogures_yogures_liquidos
# 1       mercadona-es                                     bodega_licores
# 2       mercadona-es        charcuteria_y_quesos_queso_untable_y_fresco
# 3       carrefour-es   la_despensa_yogures_y_postres_yogures_desnatados
# 4       carrefour-es                         la_despensa_helados_bombon
# ...              ...                                                ...
# 499995  carrefour-es  el_mercado_panaderia_bolleria_y_pasteleria_pan...
# 499996  carrefour-es    limpieza_y_hogar_cuidado_de_la_ropa_suavizantes
# 499997        dia-es  perfumeria_e_higiene_cuidado_corporal_cremas_c...
# 499998  mercadona-es                  aceite_especias_y_salsas_especias
# 499999        dia-es       drogueria_y_limpieza_pilas_y_bombillas_pilas
#
#                                                      name    description  \
# 0            Bebida láctea sin lactosa de fresa Hacendado         Pack-4
# 1                           Ginebra 15 botanicals Blumara        Botella
# 2       Queso fresco batido desnatado Hacendado 0% mat...        Tarrina
# 3       Yogur bífidus desnatado con lima y limón Danon...  Pack 4x120 G.
# 4            Helado After Dinner Magnum sin gluten 10 ud.         10 Ud.
# ...                                                   ...            ...
# 499995                     Barra Baguette Carrefour 250 g          250 G
# 499996  Suavizante concentrado florales jazmín Mimosín...            NaN
# 499997  DOVE loción corporal aceite de coco y leche de...            NaN
# 499998                         Piñones ibéricos Hacendado           Bote
# 499999  VARTA High energy pila alcalina LR20 blíster 2...            NaN
#
#         price  reference_price reference_unit          insert_date
# 0        1.40             2.19             kg   2020-12-23 0:00:00
# 1       10.75            15.36              L  2020-11-06 12:00:00
# 2        1.09             2.18             kg  2020-09-23 16:06:00
# 3        2.08             4.33             kg   2020-10-10 0:00:00
# 4        4.60             0.46             ud   2020-10-15 0:00:00
# ...       ...              ...            ...                  ...
# 499995   0.29             1.16             kg   2020-11-23 0:00:00
# 499996   3.55             0.05         lavado  2021-01-24 12:00:00
# 499997   5.99            31.53           €/l.   2020-12-08 0:00:00
# 499998   4.55            91.00             kg   2020-11-19 0:00:00
# 499999   4.99             2.50          €/ud.   2020-10-19 0:00:00
#
# [500000 rows x 8 columns]

# %%
df['insert_date'] = pd.to_datetime(df['insert_date'].dt.date)
df.dtypes
# Out:
# supermarket                object
# category                   object
# name                       object
# description                object
# price                     float64
# reference_price           float64
# reference_unit             object
# insert_date        datetime64[ns]
# dtype: object

# %%
# Using plotly.express
import plotly.express as px

# %%
df_supermarket.loc[:, ['supermarket', 'insert_date'] ]
#df_supermarket=df[['insert_date', 'supermarket']]
df_supermarket=df_supermarket.assign(Count=1)
df_supermarket
# Out:
# Warning: total number of rows (500000) exceeds max_rows (20000). Falling back to pandas display.
#        insert_date   supermarket  Count
# 0       2020-12-23  mercadona-es      1
# 1       2020-11-06  mercadona-es      1
# 2       2020-09-23  mercadona-es      1
# 3       2020-10-10  carrefour-es      1
# 4       2020-10-15  carrefour-es      1
# ...            ...           ...    ...
# 499995  2020-11-23  carrefour-es      1
# 499996  2021-01-24  carrefour-es      1
# 499997  2020-12-08        dia-es      1
# 499998  2020-11-19  mercadona-es      1
# 499999  2020-10-19        dia-es      1
#
# [500000 rows x 3 columns]

# %%
df2=df_supermarket.groupby(['supermarket', 'insert_date']).count().reset_index()
#df2 = df2.transpose( )
df2['supermarket'].unique()
# Out:
# array(['carrefour-es', 'dia-es', 'mercadona-es'], dtype=object)

# %%
columnas = df2.columns.values[1:]
columnas
# Out:
# array(['insert_date', 'Count'], dtype=object)

# %%
import plotly.express as px
df = px.data.stocks()
# Out:
#            date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0    2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1    2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2    2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3    2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4    2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708
# ..          ...       ...       ...       ...       ...       ...       ...
# 100  2019-12-02  1.216280  1.546914  1.425061  1.075997  1.463641  1.720717
# 101  2019-12-09  1.222821  1.572286  1.432660  1.038855  1.421496  1.752239
# 102  2019-12-16  1.224418  1.596800  1.453455  1.104094  1.604362  1.784896
# 103  2019-12-23  1.226504  1.656000  1.521226  1.113728  1.567170  1.802472
# 104  2019-12-30  1.213014  1.678000  1.503360  1.098475  1.540883  1.788185
#
# [105 rows x 7 columns]

# %%
import plotly.express as px
fig = px.line(df2, x='Count', y=df.columns,
              hover_data={"insert_date": "|%B %d, %Y"},
              title='custom tick labels')
fig.update_xaxes(
    dtick="M1",
    tickformat="%b\n%Y")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-9ca46c7f977c> in <module>
#       1 import plotly.express as px
# ----> 2 fig = px.line(df2, x='Count', y=df.columns,
#       3               hover_data={"insert_date": "|%B %d, %Y"},
#       4               title='custom tick labels')
#       5 fig.update_xaxes(
#
# /usr/local/lib/python3.8/dist-packages/plotly/express/_chart_types.py in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     260     a polyline mark in 2D space.
#     261     """
# --> 262     return make_figure(args=locals(), constructor=go.Scatter)
#     263
#     264
#
# /usr/local/lib/python3.8/dist-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    1943     apply_default_cascade(args)
#    1944
# -> 1945     args = build_dataframe(args, constructor)
#    1946     if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1947         args = process_dataframe_hierarchy(args)
#
# /usr/local/lib/python3.8/dist-packages/plotly/express/_core.py in build_dataframe(args, constructor)
#    1403     # now that things have been prepped, we do the systematic rewriting of `args`
#    1404
# -> 1405     df_output, wide_id_vars = process_args_into_dataframe(
#    1406         args, wide_mode, var_name, value_name
#    1407     )
#
# /usr/local/lib/python3.8/dist-packages/plotly/express/_core.py in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1243
#    1244                 if length and len(argument) != length:
# -> 1245                     raise ValueError(
#    1246                         "All arguments should have the same length. "
#    1247                         "The length of argument `%s` is %d, whereas the "
#
# ValueError: All arguments should have the same length. The length of argument `y` is 7, whereas the length of  previously-processed arguments ['Count'] is 557
